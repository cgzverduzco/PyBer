# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import statistics
import os
# Import NumPy and the stats module from SciPy.
import numpy as np
import scipy.stats as sts
# Import mpl to change the plot configurations using rcParams.
import matplotlib as mpl
# Import mdate for import ticks the plot
import matplotlib.dates as mdate
# Import datetime for the moth ticks
import datetime
# Import axis for the ticks location
from matplotlib.axis import Axis

# Add a variable for the files to load
city_data_to_load = os.path.join("Resources","city_data.csv")
ride_data_to_load = os.path.join("Resources","ride_data.csv")

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %%
ride_data_df
# Out:
#                     city                 date   fare        ride_id
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
# [2375 rows x 4 columns]

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
total_rides = pyber_data_df.groupby(["type"]).count()["ride_id"]
total_rides
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
total_drivers = city_data_df.groupby(["type"]).sum()["driver_count"]
total_drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
total_fares = pyber_data_df.groupby(["type"]).sum()["fare"]
total_fares
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
# Calculate the percentage of fare for each city type.
ave_fare_ride = pyber_data_df.groupby(["type"]).sum()["fare"] / pyber_data_df.groupby(["type"]).count()["ride_id"]
ave_fare_ride
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
ave_fare_driver = pyber_data_df.groupby(["type"]).sum()["fare"] / city_data_df.groupby(["type"]).sum()["driver_count"]
ave_fare_driver
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 

# dictionary of lists 
pyber_summary_dict = {
        'Total Rides': total_rides, 
        'Total Drivers': total_drivers, 
        'Total Fares': total_fares,
        'Averange per Ride': ave_fare_ride,
        'Averange per Driver': ave_fare_driver}

# Create a dataframe form a dictionary
pyber_summary_df = pd.DataFrame(pyber_summary_dict)

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

# %%
#  8. Format the columns.
pyber_summary_df["Total Rides"] = pyber_summary_df["Total Rides"].map("{:,}".format)
pyber_summary_df["Total Drivers"] = pyber_summary_df["Total Drivers"].map("{:,}".format)
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2f}".format)
pyber_summary_df["Averange per Ride"] = pyber_summary_df["Averange per Ride"].map("${:,.2f}".format)
pyber_summary_df["Averange per Driver"] = pyber_summary_df["Averange per Driver"].map("${:,.2f}".format)
pyber_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Averange per Ride  \
# Rural            125            78   $4,327.93            $34.62
# Suburban         625           490  $19,356.33            $30.97
# Urban          1,625         2,405  $39,854.38            $24.53
#
#          Averange per Driver
# Rural                 $55.49
# Suburban              $39.50
# Urban                 $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
fares_per_date = pyber_data_df.groupby(["type","date"]).sum()["fare"]
fares_per_date
# Out:
# type   date
# Rural  2019-01-01 09:45:36    43.69
#        2019-01-02 11:18:32    52.12
#        2019-01-03 19:51:01    19.90
#        2019-01-04 03:31:26    24.88
#        2019-01-06 07:38:40    47.33
#                               ...
# Urban  2019-05-08 04:20:00    21.99
#        2019-05-08 04:39:49    18.45
#        2019-05-08 07:29:01    18.55
#        2019-05-08 11:38:35    19.77
#        2019-05-08 13:10:18    18.04
# Name: fare, Length: 2375, dtype: float64

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
fares_per_date = fares_per_date.reset_index()
fares_per_date
# Out:
#        type                 date   fare
# 0     Rural  2019-01-01 09:45:36  43.69
# 1     Rural  2019-01-02 11:18:32  52.12
# 2     Rural  2019-01-03 19:51:01  19.90
# 3     Rural  2019-01-04 03:31:26  24.88
# 4     Rural  2019-01-06 07:38:40  47.33
# ...     ...                  ...    ...
# 2370  Urban  2019-05-08 04:20:00  21.99
# 2371  Urban  2019-05-08 04:39:49  18.45
# 2372  Urban  2019-05-08 07:29:01  18.55
# 2373  Urban  2019-05-08 11:38:35  19.77
# 2374  Urban  2019-05-08 13:10:18  18.04
#
# [2375 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
# Syntax DataFrame.pivot(self, index=None, columns=None, values=None)
fares_per_date = fares_per_date.pivot(index="date", columns="type", values="fare")
fares_per_date.head(10)
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# 2019-01-01 09:45:36  43.69       NaN    NaN
# 2019-01-01 12:32:48    NaN     25.56    NaN
# 2019-01-01 14:40:14    NaN       NaN   5.42
# 2019-01-01 14:42:25    NaN       NaN  12.31
# 2019-01-01 14:52:06    NaN     31.15    NaN

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
fares_1q = fares_per_date.loc['2019-01-01':'2019-04-29']
fares_1q
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-28 14:28:36    NaN       NaN  11.46
# 2019-04-28 16:29:16    NaN       NaN  36.42
# 2019-04-28 17:26:52    NaN       NaN  31.43
# 2019-04-28 17:38:09    NaN     34.87    NaN
# 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
fares_1q.index = pd.to_datetime(fares_1q.index)

# %%
# Check that the datatype for the index is datetime using df.info()
fares_1q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2196 entries, 2019-01-01 00:08:16 to 2019-04-28 19:35:03
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     114 non-null    float64
#  1   Suburban  573 non-null    float64
#  2   Urban     1509 non-null   float64
# dtypes: float64(3)
# memory usage: 68.6 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
# Syntax : DataFrame.resample(rule, axis=0, closed=None, label=None, convention='start', kind=None, loffset=None, 
# base=None, on=None, level=None, origin='start_day', offset=None)

fares_1q_week = fares_1q.resample("W").sum()
fares_1q_week.head(10)
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# Create the variables for x and y axis
dates = list(fares_1q_week.index.values)
urban_fare_1q_week = fares_1q_week["Urban"]
suburban_fare_1q_week = fares_1q_week["Suburban"]
rural_fare_1q_week = fares_1q_week["Rural"]

# %% [markdown]
# ## Matplotlib

# %%
# Create the plot Create a Line Chart Using the MATLAB Method
plt.subplots(figsize=(18, 6))
plt.plot(dates,rural_fare_1q_week, label="Rural")
plt.plot(dates,suburban_fare_1q_week, label="Suburban")
plt.plot(dates,urban_fare_1q_week, label="Urban")

# Incorporate the other graph properties
plt.title("Total Fare by City Type", fontsize=20)
plt.ylabel("Fare ($USD)", fontsize=20)

# label = ax.set_xlabel('xlabel', ha='left', va = 'top', )#fontsize = 9)
plt.xlabel("2019", fontsize=12, ha="left") # the alignment label is inherited from text.

# Adding the grid
plt.grid(True)

# Add the legend.
lgnd = plt.legend(fontsize="12",loc="center", title="City Types")

# Config the ticks. Set the locator
locator = mdate.MonthLocator()
fmt = mdate.DateFormatter('%b')
X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)

# set limits
plt.xlim([datetime.date(2019, 1, 1), datetime.date(2019, 4, 29)])

# Save the figure.
plt.savefig("analysis/PyBer_fare_summary_1.png", bbox_inches = 'tight')

# Show the plot
plt.show()

# %% [markdown]
# ## Object-oriented

# %%
fig, ax = plt.subplots(figsize =(18, 6))
ax.plot(dates,urban_fare_1q_week, label="Urban")
ax.plot(dates,suburban_fare_1q_week, label="Suburban")
ax.plot(dates,rural_fare_1q_week, label="Rural")

# Incorporate the other graph properties
ax.set_title("Total Fare by City Type", fontsize=20)
ax.set_ylabel("Fare ($USD)", fontsize=20)
ax.set_xlabel("2019", fontsize=12, loc="left")

# Adding the grid
ax.grid(True)

# Add the legend.
leg = ax.legend(fontsize="12",loc="center", title="City Types")

# Config the ticks. Set the locator
months = mdate.MonthLocator()  # every month
months_fmt = mdate.DateFormatter("%b")
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(months_fmt)

# set limits
ax.set_xlim([datetime.date(2019, 1, 1), datetime.date(2019, 4, 29)])

# Save the figure.
plt.savefig("analysis/PyBer_fare_summary_2.png",pad_inches=0.5)
plt.show()

# %%
# The function ax.set_xlabel(loc="left") release on 3.4 version
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.4.2

# %% [markdown]
# ## Rides per date

# %%
# Using groupby() to create a new DataFrame showing the sum of the rides 
# for each date where the indices are the city type and date.
rides_per_date = pyber_data_df.groupby(["type","date"]).count()["ride_id"]
# Reset the index on the DataFrame you created. This is needed to use the 'pivot()' function.
rides_per_date = rides_per_date.reset_index()
# Create a pivot table with the 'date' as the index, the columns ='type', and values='ride_id' 
# to get the total rides for each type of city by the date.
rides_per_date = rides_per_date.pivot(index="date", columns="type", values="ride_id")
# Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-05-12'.
rides_1q = rides_per_date.loc['2019-01-01':'2019-05-12']
# Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
rides_1q.index = pd.to_datetime(rides_1q.index)
# Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
rides_1q_week = rides_1q.resample("W").sum()
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
# Create the variables for x and y axis
datesR = list(rides_1q_week.index.values)
urban_ride_1q_week = rides_1q_week["Urban"]
suburban_ride_1q_week = rides_1q_week["Suburban"]
rural_ride_1q_week = rides_1q_week["Rural"]

fig, ax = plt.subplots(figsize =(18, 6))
ax.plot(datesR,urban_ride_1q_week, label="Urban")
ax.plot(datesR,suburban_ride_1q_week, label="Suburban")
ax.plot(datesR,rural_ride_1q_week, label="Rural")

# Incorporate the other graph properties
ax.set_title("Total Rides by City Type", fontsize=20)
ax.set_ylabel("Rides count", fontsize=20)
ax.set_xlabel("2019", fontsize=12, loc="left")

# Adding the grid
ax.grid(True)

# Add the legend.
leg = ax.legend(fontsize="12",loc="center", title="City Types")

# Config the ticks. Set the locator
months = mdate.MonthLocator()  # every month
months_fmt = mdate.DateFormatter("%b")
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(months_fmt)

# set limits
ax.set_xlim([datetime.date(2019, 1, 1), datetime.date(2019, 5, 13)])

# Save the figure.
plt.savefig("analysis/PyBer_ride_summary_3.png",pad_inches=0.5)
plt.show()

# %%
rides_1q_week
# Out:
# type        Rural  Suburban  Urban
# date
# 2019-01-06    5.0      22.0   66.0
# 2019-01-13    3.0      35.0   80.0
# 2019-01-20    8.0      41.0   84.0
# 2019-01-27    6.0      34.0   84.0
# 2019-02-03    9.0      32.0   88.0
# 2019-02-10    4.0      31.0   94.0
# 2019-02-17    3.0      34.0   86.0
# 2019-02-24   11.0      43.0  103.0
# 2019-03-03    5.0      30.0   88.0
# 2019-03-10    8.0      33.0  100.0
# 2019-03-17    5.0      30.0   85.0
# 2019-03-24    5.0      33.0   96.0
# 2019-03-31    7.0      35.0   86.0
# 2019-04-07   14.0      38.0   92.0
# 2019-04-14    7.0      24.0   94.0
# 2019-04-21    8.0      37.0   91.0
# 2019-04-28    6.0      41.0   92.0
# 2019-05-05    7.0      41.0   91.0
# 2019-05-12    4.0      11.0   25.0
